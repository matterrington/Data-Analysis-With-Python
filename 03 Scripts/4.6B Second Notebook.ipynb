# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ### Question 3

# %%
# Import pickle dataframe

df_ords_pkl = pd.read_pickle(r'/Users/matthewerrington/08-2020 Instacart Basket Analysis/02 Data/Prepared Data/orders_products_combined.pkl')

# %% [markdown]
# ### Question 4

# %%
df_ords_pkl.shape
# Out:
# (32434489, 13)

# %%
df_ords_pkl.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  order_id  user_id eval_set  user_order_count  \
# 0           0             0   2539329        1    prior                 1
# 1           0             0   2539329        1    prior                 1
# 2           0             0   2539329        1    prior                 1
# 3           0             0   2539329        1    prior                 1
# 4           0             0   2539329        1    prior                 1
#
#    orders_day_of_week  order_hour_of_day  days_since_prior_order  product_id  \
# 0                   2                  8                     NaN         196
# 1                   2                  8                     NaN       14084
# 2                   2                  8                     NaN       12427
# 3                   2                  8                     NaN       26088
# 4                   2                  8                     NaN       26405
#
#    add_to_cart_order  reordered _merge
# ...

# %% [markdown]
# ### Question 5

# %%
# Import prepared products dataframe
df_prods_chck = pd.read_csv(r'/Users/matthewerrington/08-2020 Instacart Basket Analysis/02 Data/Prepared Data/prods_checked.csv', index_col = False)

# %%
df_prods_chck.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %%
# Perform merge on product and orders dataframes

df_IC_large = df_ords_pkl.merge(df_prods_chck, on = ['product_id'])

# %% [markdown]
# ### Question 6

# %%
# Check merge success

df_IC_large['_merge'].value_counts()
# Out:
# both          32404859
# right_only           0
# left_only            0
# Name: _merge, dtype: int64

# %%
df_IC_large.head()
# Out:
#    Unnamed: 0_x  Unnamed: 0.1  order_id  user_id eval_set  user_order_count  \
# 0             0             0   2539329        1    prior                 1
# 1             1             1   2398795        1    prior                 2
# 2             2             2    473747        1    prior                 3
# 3             3             3   2254736        1    prior                 4
# 4             4             4    431534        1    prior                 5
#
#    orders_day_of_week  order_hour_of_day  days_since_prior_order  product_id  \
# 0                   2                  8                     NaN         196
# 1                   3                  7                    15.0         196
# 2                   3                 12                    21.0         196
# 3                   4                  7                    29.0         196
# 4                   4                 15                    28.0         196
#
# ...

# %% [markdown]
# ### Question 7

# %%
# Export df_IC_large as PKL file

path = r'/Volumes/Seagate Backup Plus Drive/Career Foundry/08-2020 Instacart Basket Analysis'
df_IC_large.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged.pkl'))
