# %% [markdown]
# # Part 1

# %%
import pandas as pd
import numpy as np
import os

# %%
customer = pd.read_csv(r'/Volumes/Seagate Backup Plus Drive/Career Foundry/08-2020 Instacart Basket Analysis/02 Data/Original Data/customers.csv', index_col = False)

# %%
customer.head()
# Out:
#    user_id First Name    Surnam  Gender       STATE  Age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    n_dependants fam_status  income
# 0             3    married  165665
# 1             0     single   59285
# 2             2    married   99568
# 3             0     single   42049
# 4             1    married   40374

# %%
customer.shape
# Out:
# (206209, 10)

# %%
customer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206209 entries, 0 to 206208
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   user_id       206209 non-null  int64
#  1   First Name    194950 non-null  object
#  2   Surnam        206209 non-null  object
#  3   Gender        206209 non-null  object
#  4   STATE         206209 non-null  object
#  5   Age           206209 non-null  int64
#  6   date_joined   206209 non-null  object
#  7   n_dependants  206209 non-null  int64
#  8   fam_status    206209 non-null  object
#  9   income        206209 non-null  int64
# dtypes: int64(4), object(6)
# memory usage: 15.7+ MB

# %%
customer.describe()
# Out:
#              user_id            Age   n_dependants         income
# count  206209.000000  206209.000000  206209.000000  206209.000000
# mean   103105.000000      49.501646       1.499823   94632.852548
# std     59527.555167      18.480962       1.118433   42473.786988
# min         1.000000      18.000000       0.000000   25903.000000
# 25%     51553.000000      33.000000       0.000000   59874.000000
# 50%    103105.000000      49.000000       1.000000   93547.000000
# 75%    154657.000000      66.000000       3.000000  124244.000000
# max    206209.000000      81.000000       3.000000  593901.000000

# %% [markdown]
# ### Question 4

# %%
# Change user_id to str since it's a dimension.
customer['user_id'] = customer['user_id'].astype('str')

# %%
customer['user_id'].dtype
# Out:
# dtype('O')

# %%
# Change column names
customer.rename(columns = {'Surnam' : 'last_name'}, inplace = True)

# %%
customer.rename(columns = {'First Name' : 'first_name'}, inplace = True)

# %%
customer.rename(columns = {'STATE' : 'state'}, inplace = True)

# %%
customer.head()
# Out:
#   user_id first_name last_name  Gender       state  Age date_joined  \
# 0   26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1   33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2   65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3  125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4  130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    n_dependants fam_status  income
# 0             3    married  165665
# 1             0     single   59285
# 2             2    married   99568
# 3             0     single   42049
# 4             1    married   40374

# %%
# Not sure which columns to drop until I know more about the questions being asked.

# %% [markdown]
# ### Question 5

# %%
# Find missing values
customer.isnull().sum()
# Out:
# user_id             0
# first_name      11259
# last_name           0
# Gender              0
# state               0
# Age                 0
# date_joined         0
# n_dependants        0
# fam_status          0
# income              0
# dtype: int64

# %%
# Delete name columns - roughly 5% of names missing. 
# Names do not help us understand the makeup of a customer.

# %%
customer_2 = customer.drop(columns = ['first_name', 'last_name'])

# %%
customer_2.head()
# Out:
#   user_id  Gender       state  Age date_joined  n_dependants fam_status  \
# 0   26711  Female    Missouri   48    1/1/2017             3    married
# 1   33890  Female  New Mexico   36    1/1/2017             0     single
# 2   65803    Male       Idaho   35    1/1/2017             2    married
# 3  125935  Female        Iowa   40    1/1/2017             0     single
# 4  130797  Female    Maryland   26    1/1/2017             1    married
#
#    income
# 0  165665
# 1   59285
# 2   99568
# 3   42049
# 4   40374

# %%
# Find duplicates
customer_dups = customer_2[customer_2.duplicated()]

# %%
customer_dups
# Out:
# Empty DataFrame
# Columns: [user_id, Gender, state, Age, date_joined, n_dependants, fam_status, income]
# Index: []

# %%
# No duplicates found

# %% [markdown]
# ### Question 6

# %%
ords_prods = pd.read_pickle(r'/Volumes/Seagate Backup Plus Drive/Career Foundry/08-2020 Instacart Basket Analysis/02 Data/Prepared Data/ords_prods_agg.pkl')

# %%
ords_prods.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32404859 entries, 0 to 32404858
# Data columns (total 28 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   Unnamed: 0_x            int64
#  1   Unnamed: 0.1            int64
#  2   order_id                int64
#  3   user_id                 int64
#  4   eval_set                object
#  5   user_order_count        int64
#  6   orders_day_of_week      int64
#  7   order_hour_of_day       int64
#  8   days_since_prior_order  float64
#  9   product_id              int64
#  10  add_to_cart_order       int64
#  11  reordered               int64
#  12  _merge                  category
#  13  Unnamed: 0_y            int64
#  14  product_name            object
#  15  aisle_id                int64
#  16  department_id           int64
#  17  prices                  float64
#  18  price_range_loc         object
#  19  busiest_day             object
#  20  busiest_days            object
# ...

# %%
ords_prods.drop(columns = ['Unnamed: 0_x', 'Unnamed: 0.1'])
# Out:
#           order_id  user_id eval_set  user_order_count  orders_day_of_week  \
# 0          2539329        1    prior                 1                   2
# 1          2398795        1    prior                 2                   3
# 2           473747        1    prior                 3                   3
# 3          2254736        1    prior                 4                   4
# 4           431534        1    prior                 5                   4
# ...            ...      ...      ...               ...                 ...
# 32404854   1320836   202557    prior                17                   2
# 32404855     31526   202557    prior                18                   5
# 32404856    758936   203436    prior                 1                   2
# 32404857   2745165   203436    prior                 2                   3
# 32404858   3093936   205420    prior                 1                   4
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# ...

# %%
ords_prods['user_id']=ords_prods['user_id'].astype('str')

# %%
# Merge dataframes

all_merged = ords_prods.merge(customer_2, on = 'user_id')

# %%
all_merged.head()
# Out:
#    Unnamed: 0_x  Unnamed: 0.1  order_id user_id eval_set  user_order_count  \
# 0             0             0   2539329       1    prior                 1
# 1             1             1   2398795       1    prior                 2
# 2             2             2    473747       1    prior                 3
# 3             3             3   2254736       1    prior                 4
# 4             4             4    431534       1    prior                 5
#
#    orders_day_of_week  order_hour_of_day  days_since_prior_order  product_id  \
# 0                   2                  8                     NaN         196
# 1                   3                  7                    15.0         196
# 2                   3                 12                    21.0         196
# 3                   4                  7                    29.0         196
# 4                   4                 15                    28.0         196
#
# ...

# %%
# Export ords_prods_agg as PKL file

path = r'/Volumes/Seagate Backup Plus Drive/Career Foundry/08-2020 Instacart Basket Analysis'
all_merged.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'all_merged.pkl'))
